# %% [markdown]
# ## Melbourne LGA census information

# %%
import pandas as pd
import numpy as np
from flask import Flask, jsonify

import requests 

# from sqlalchemy import create_engine, Table, MetaData, text, func
# from sqlalchemy.orm import Session

import pandas as pd
import numpy as np

from flask import Flask, jsonify

# engine = create_engine(f"postgresql://postgres:@localhost/melbournehousingdb")
# metadata = MetaData()
# metadata.bind = engine

# %%
url = f"http://127.0.0.1:5000/api/people_dwellings"
response = requests.get(url)
if response.status_code == 200:
        df = pd.json_normalize(response.json())

# %%
# Check that the df exists
df
# Out:
#    lga_code_2021  opds_f_ap_i_1or2_sty_blk_ps  opds_f_ap_i_3_sty_blk_psns  \
# 0       LGA20110                           74                           0
# 1       LGA20260                           31                           7
# 2       LGA20570                         1462                         129
# 3       LGA20660                         3375                         790
# 4       LGA20740                          329                          30
# ..           ...                          ...                         ...
# 77      LGA27450                          380                          15
# 78      LGA27630                           20                           0
# 79      LGA29399                           57                          50
# 80      LGA29499                            0                           0
# 81      LGA29799                            0                           0
#
#     opds_f_ap_i_4to8_sty_blk_ps  opds_f_ap_i_9_m_sty_blk_ps  \
# ...

# %%
# make dwellings

dwellings_df = pd.DataFrame(df)
dwellings_df
# Out:
#    lga_code_2021  opds_f_ap_i_1or2_sty_blk_ps  opds_f_ap_i_3_sty_blk_psns  \
# 0       LGA20110                           74                           0
# 1       LGA20260                           31                           7
# 2       LGA20570                         1462                         129
# 3       LGA20660                         3375                         790
# 4       LGA20740                          329                          30
# ..           ...                          ...                         ...
# 77      LGA27450                          380                          15
# 78      LGA27630                           20                           0
# 79      LGA29399                           57                          50
# 80      LGA29499                            0                           0
# 81      LGA29799                            0                           0
#
#     opds_f_ap_i_4to8_sty_blk_ps  opds_f_ap_i_9_m_sty_blk_ps  \
# ...

# %%
# If there are missing values, check them:
# dwellings_df[['opds_sd_r_t_h_th_1_sty_dwgs', 'opds_flt_apt_att_house_ds']] = dwellings_df[['opds_sd_r_t_h_th_1_sty_dwgs', 'opds_flt_apt_att_house_ds']].fillna(0)

# %%
dwellings_df['Single Storey Total People'] = dwellings_df['opds_separate_house_persons'] + dwellings_df['opds_sd_r_t_h_th_1_sty_psns'] + dwellings_df['opds_flt_apt_att_house_ps']

# %%
dwellings_df['Two Storey Total People'] = dwellings_df['opds_sd_r_t_h_th_2_m_sty_psns'] + dwellings_df['opds_f_ap_i_1or2_sty_blk_ps']

# %%
dwellings_df['Three Storey Total People'] = dwellings_df['opds_f_ap_i_3_sty_blk_psns'] + dwellings_df['opds_f_ap_i_1or2_sty_blk_ps']

# %%
dwellings_df['Four Storey and Above Total'] = dwellings_df['opds_f_ap_i_4to8_sty_blk_ps'] + dwellings_df['opds_f_ap_i_9_m_sty_blk_ps']

# %%
dwellings_df
# Out:
#    lga_code_2021  opds_f_ap_i_1or2_sty_blk_ps  opds_f_ap_i_3_sty_blk_psns  \
# 0       LGA20110                           74                           0
# 1       LGA20260                           31                           7
# 2       LGA20570                         1462                         129
# 3       LGA20660                         3375                         790
# 4       LGA20740                          329                          30
# ..           ...                          ...                         ...
# 77      LGA27450                          380                          15
# 78      LGA27630                           20                           0
# 79      LGA29399                           57                          50
# 80      LGA29499                            0                           0
# 81      LGA29799                            0                           0
#
#     opds_f_ap_i_4to8_sty_blk_ps  opds_f_ap_i_9_m_sty_blk_ps  \
# ...

# %%
# Convert dataframe into json object
json = dwellings_df.to_json()
  
# Print json object
print(json)
# Out:
# {"lga_code_2021":{"0":"LGA20110","1":"LGA20260","2":"LGA20570","3":"LGA20660","4":"LGA20740","5":"LGA20830","6":"LGA20910","7":"LGA21010","8":"LGA21110","9":"LGA21180","10":"LGA21270","11":"LGA21370","12":"LGA21450","13":"LGA21610","14":"LGA21670","15":"LGA21750","16":"LGA21830","17":"LGA21890","18":"LGA22110","19":"LGA22170","20":"LGA22250","21":"LGA22310","22":"LGA22410","23":"LGA22490","24":"LGA22620","25":"LGA22670","26":"LGA22750","27":"LGA22830","28":"LGA22910","29":"LGA22980","30":"LGA23110","31":"LGA23190","32":"LGA23270","33":"LGA23350","34":"LGA23430","35":"LGA23670","36":"LGA23810","37":"LGA23940","38":"LGA24130","39":"LGA24210","40":"LGA24250","41":"LGA24330","42":"LGA24410","43":"LGA24600","44":"LGA24650","45":"LGA24780","46":"LGA24850","47":"LGA24900","48":"LGA24970","49":"LGA25060","50":"LGA25150","51":"LGA25250","52":"LGA25340","53":"LGA25430","54":"LGA25490","55":"LGA25620","56":"LGA25710","57":"LGA25810","58":"LGA25900","59":"LGA25990","60":"LGA26080","61":"LGA26170
# ...
